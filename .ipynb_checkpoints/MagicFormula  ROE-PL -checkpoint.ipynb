# %% [markdown]
# # Magic Formula

# %%
import numpy as np
import pandas as pd
import string
import warnings
warnings.filterwarnings('ignore')
import requests

# %%
url = 'http://www.fundamentus.com.br/resultado.php'

# %%
header = {
  "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36"  
 }

r = requests.get(url, headers=header)

# %%
#na tabela do site fundamentus o decimal é colocado como virgula
df = pd.read_html(r.text,  decimal=',', thousands='.')[0]

# %%
df.columns
# Out:
# Index(['Papel', 'Cotação', 'P/L', 'P/VP', 'PSR', 'Div.Yield', 'P/Ativo',
#        'P/Cap.Giro', 'P/EBIT', 'P/Ativ Circ.Liq', 'EV/EBIT', 'EV/EBITDA',
#        'Mrg Ebit', 'Mrg. Líq.', 'Liq. Corr.', 'ROIC', 'ROE', 'Liq.2meses',
#        'Patrim. Líq', 'Dív.Brut/ Patrim.', 'Cresc. Rec.5a'],
#       dtype='object')

# %%
#Os indicadores com % são raspados como strings
#Este for transforma eles em float
for coluna in ['Div.Yield', 'Mrg Ebit', 'Mrg. Líq.', 'ROIC', 'ROE', 'Cresc. Rec.5a']:
    df[coluna] = df[coluna].str.replace('.', '')
    df[coluna] = df[coluna].str.replace(',', '.')
    df[coluna] = df[coluna].str.rstrip('%').astype('float') / 100

# %% [markdown]
# ## Analisando os dados

# %%
#liquidez diária 
df = df[df['Liq.2meses'] > 100000]
df.shape
# Out:
# (305, 21)

# %% [markdown]
# ## Joel Greenblat

# %%
df[:5]
# Out:
#     Papel  Cotação     P/L  P/VP    PSR  Div.Yield  P/Ativo  P/Cap.Giro  \
# 16  HBSA3     2.60 -242.19  1.49  1.118        0.0    0.311        3.31
# 24  SMFT3    15.84 -103.84  2.22  8.591        0.0    0.771        5.25
# 34  ALPA3     8.43  -51.87  1.04  1.385        0.0    0.708        2.93
# 36  MGLU3     3.57  -48.29  2.26  0.646        0.0    0.638        3.39
# 38  ALPA4     7.68  -47.25  0.95  1.262        0.0    0.645        2.67
#
#     P/EBIT  P/Ativ Circ.Liq  ...  EV/EBITDA  Mrg Ebit  Mrg. Líq.  Liq. Corr.  \
# 16    6.78            -0.53  ...       8.94    0.1649    -0.0046        1.86
# 24  -85.74            -2.15  ...      12.32   -0.1002    -0.0827        2.01
# 34   13.44             8.65  ...      11.11    0.1031    -0.0269        2.50
# 36   20.70            -4.65  ...      12.24    0.0312    -0.0134        1.48
# 38   12.24             7.88  ...      10.25    0.1031    -0.0269        2.50
#
#       ROIC     ROE   Liq.2meses   Patrim. Líq  Dív.Brut/ Patrim.  \
# 16  0.0536 -0.0061   10950600.0  1.330800e+09               3.42
# 24 -0.0122 -0.0214   33411500.0  4.186390e+09               0.82
# 34  0.0595 -0.0201     104421.0  5.510850e+09               0.25
# 36  0.0456 -0.0469  392733000.0  1.064870e+10               0.67
# 38  0.0595 -0.0201   64649200.0  5.510850e+09               0.25
#
#     Cresc. Rec.5a
# 16         0.1952
# 24        -0.0287
# 34         0.0230
# 36         0.2608
# 38         0.0230
#
# [5 rows x 21 columns]

# %%
data = df
data = data[data['ROE'] > 0.0]
data = data[data['P/L'] > 3.0]
data = data[data['Mrg. Líq.'] > 0.10]
data = data[data['ROIC'] > 0.0]
#data = data[data['EV/EBITDA'] > 0.0]

# %%
print(data.shape, df.shape)
# Out:
# (99, 21) (305, 21)

# %%
num_acoes = data.shape[0]

# %% [markdown]
# ## Rankings

# %%
RankingROE = pd.DataFrame()
RankingROE['pos_roe'] = range(1,num_acoes)
RankingPL = pd.DataFrame()
RankingPL['pos_pl'] = range(1,num_acoes)

# %%
RankingROE['Papel'] = data.sort_values(by=['ROE'], ascending=False)['Papel'][:(num_acoes-1)].values
RankingROE['ROE Value'] = data.sort_values(by=['ROE'], ascending=False)['ROE'][:(num_acoes-1)].values

# %%
RankingPL['Papel'] = data.sort_values(by=['P/L'], ascending=True)['Papel'][:(num_acoes-1)].values
RankingPL['P/L Value'] = data.sort_values(by=['P/L'], ascending=True)['P/L'][:(num_acoes-1)].values

# %%
RankingPL[:5]
# Out:
#    pos_pl  Papel  P/L Value
# 0       1  EUCA4       3.13
# 1       2  GGBR3       3.20
# 2       3  CBAV3       3.37
# 3       4  GGBR4       3.56
# 4       5  CAMB3       3.59

# %%
RankingROE[:5]
# Out:
#    pos_roe  Papel  ROE Value
# 0        1  CGAS5     1.7540
# 1        2  UNIP6     0.5722
# 2        3  UNIP3     0.5722
# 3        4  KEPL3     0.5226
# 4        5  TASA4     0.5077

# %% [markdown]
# ## Soma das posições - Tabela das ações mais descontadas

# %%
ranking = pd.merge(RankingPL, RankingROE)

# %%
ranking['pts'] = ranking["pos_pl"] + ranking["pos_roe"]
ranking[:3]
# Out:
#    pos_pl  Papel  P/L Value  pos_roe  ROE Value  pts
# 0       1  EUCA4       3.13       78     0.1279   79
# 1       2  GGBR3       3.20       30     0.2408   32
# 2       3  CBAV3       3.37       58     0.1703   61

# %%
rank = ranking.sort_values('pts')
rank = rank[["Papel","P/L Value","pos_pl","ROE Value","pos_roe","pts"]]
rank.set_index("Papel",inplace=True)
rank.reset_index(inplace=True)
rank.index = rank.index + 1
rank.head(5)
# Out:
#    Papel  P/L Value  pos_pl  ROE Value  pos_roe  pts
# 1  TASA4       3.64       6     0.5077        5   11
# 2  TASA3       3.66       7     0.5077        6   13
# 3  KEPL3       3.70       9     0.5226        4   13
# 4  CAMB3       3.59       5     0.3714       15   20
# 5  VALE3       3.68       8     0.4344       13   21

# %% [markdown]
# ## Tabela sem a posição do PL e do ROE

# %%
rank = ranking.sort_values('pts')
rank = rank[["Papel","P/L Value","ROE Value","pts"]]
rank.set_index("Papel",inplace=True)
rank.reset_index(inplace=True)
rank.index = rank.index + 1
rank.head(30)
# Out:
#      Papel  P/L Value  ROE Value  pts
# 1    TASA4       3.64     0.5077   11
# 2    TASA3       3.66     0.5077   13
# 3    KEPL3       3.70     0.5226   13
# 4    CAMB3       3.59     0.3714   20
# 5    VALE3       3.68     0.4344   21
# 6    UNIP6       4.91     0.5722   25
# 7    UNIP3       4.70     0.5722   25
# 8   KLBN11       4.50     0.4567   28
# 9    KLBN3       4.60     0.4567   28
# 10   KLBN4       4.49     0.4567   28
# 11   FESA4       4.03     0.3495   29
# 12   GGBR3       3.20     0.2408   32
# 13   GGBR4       3.56     0.2408   35
# 14   RSUL4       6.08     0.4677   43
# 15   RECV3       4.68     0.3027   44
# 16   RANI3       5.65     0.2947   53
# 17   ETER3       4.16     0.2035   53
# 18   WIZC3       6.27     0.3559   55
# 19   CEBR6       4.36     0.2009   57
# 20   CEBR3       4.41     0.2009   59
# 21   CBAV3       3.37     0.1703   61
# 22   LEVE3       6.96     0.3563   61
# 23   SHUL4       5.92     0.2422   62
# 24   CGAS5       9.19     1.7540   63
# 25   CPFE3       7.02     0.3137   67
# 26   NEOE3       3.94     0.1686   69
# 27   VULC3       6.90     0.2785   69
# 28   PRIO3       8.24     0.3312   73
# 29   ROMI3       5.81     0.2009   74
# 30   SLCE3       7.24     0.2756   74

# %%
def retirar_duplicados(rank):
    Ticker = rank['Papel'].str.extract(r'([A-Z]{4})')
    rank["Ticker"] = Ticker
    rank.set_index("Ticker",inplace=True)
    rank = rank[~rank.index.duplicated(keep='first')]
    rank.reset_index(inplace=True)
    rank.index = rank.index + 1
    rank.drop('Ticker',axis=1,inplace=True)
    return rank


rank = ranking.sort_values('pts')
rank = rank[["Papel","P/L Value","ROE Value","pts"]]
rank = retirar_duplicados(rank)

rank.head(30)
# Out:
#      Papel  P/L Value  ROE Value  pts
# 1    TASA4       3.64     0.5077   11
# 2    KEPL3       3.70     0.5226   13
# 3    CAMB3       3.59     0.3714   20
# 4    VALE3       3.68     0.4344   21
# 5    UNIP6       4.91     0.5722   25
# 6   KLBN11       4.50     0.4567   28
# 7    FESA4       4.03     0.3495   29
# 8    GGBR3       3.20     0.2408   32
# 9    RSUL4       6.08     0.4677   43
# 10   RECV3       4.68     0.3027   44
# 11   RANI3       5.65     0.2947   53
# 12   ETER3       4.16     0.2035   53
# 13   WIZC3       6.27     0.3559   55
# 14   CEBR6       4.36     0.2009   57
# 15   CBAV3       3.37     0.1703   61
# 16   LEVE3       6.96     0.3563   61
# 17   SHUL4       5.92     0.2422   62
# 18   CGAS5       9.19     1.7540   63
# 19   CPFE3       7.02     0.3137   67
# 20   NEOE3       3.94     0.1686   69
# 21   VULC3       6.90     0.2785   69
# 22   PRIO3       8.24     0.3312   73
# 23   ROMI3       5.81     0.2009   74
# 24   SLCE3       7.24     0.2756   74
# 25   AURE3       5.41     0.1880   77
# 26   EUCA4       3.13     0.1279   79
# 27   LOGN3      10.27     0.4645   79
# 28   CURY3      10.18     0.4388   81
# 29   TGMA3       6.96     0.2186   81
# 30   TAEE3       8.08     0.2328   83
